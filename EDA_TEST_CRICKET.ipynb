# %% [markdown]
# <a href="https://colab.research.google.com/github/RatnaShekar11/Basic-ML/blob/main/EDA_TEST_CRICKET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **READ THE DATASET('TEST CRICKET')**

# %%
df = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                Player       Span  Mat  ... 100  50   0 Unnamed: 11
# 0           0  SR Tendulkar (INDIA)  1989-2013  200  ...  51  68  14         NaN
# 1           1      RT Ponting (AUS)  1995-2012  168  ...  41  62  17         NaN
# 2           2    JH Kallis (ICC/SA)  1995-2013  166  ...  45  58  16         NaN
# 3           3  R Dravid (ICC/INDIA)  1996-2012  164  ...  36  63   8         NaN
# 4           4         AN Cook (ENG)  2006-2018  161  ...  33  57   9         NaN
#
# [5 rows x 13 columns]

# %%
df.tail()
# Out:
#       Unnamed: 0                Player       Span  Mat  ... 100 50  0 Unnamed: 11
# 2996          46       CA Snedden (NZ)  1947-1947    1  ...   -  -  -         NaN
# 2997          47      VN Swamy (INDIA)  1955-1955    1  ...   -  -  -         NaN
# 2998          48  Usman Shinwari (PAK)  2019-2019    1  ...   -  -  -         NaN
# 2999          49    CM Willoughby (SA)  2003-2003    2  ...   -  -  -         NaN
# 3000           0       JW Wilson (AUS)  1956-1956    1  ...   -  -  -         NaN
#
# [5 rows x 13 columns]

# %%
df.shape
# Out:
# (3001, 13)

# %%
df.describe()
# Out:
#         Unnamed: 0          Mat  Unnamed: 11
# count  3001.000000  3001.000000          0.0
# mean     24.491836    17.427191          NaN
# std      14.437798    24.954654          NaN
# min       0.000000     1.000000          NaN
# 25%      12.000000     2.000000          NaN
# 50%      24.000000     7.000000          NaN
# 75%      37.000000    21.000000          NaN
# max      49.000000   200.000000          NaN

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS',
#        'Ave', '100', '50', '0', 'Unnamed: 11'],
#       dtype='object')

# %%
df.isnull()
# Out:
#       Unnamed: 0  Player   Span    Mat  ...    100     50      0  Unnamed: 11
# 0          False   False  False  False  ...  False  False  False         True
# 1          False   False  False  False  ...  False  False  False         True
# 2          False   False  False  False  ...  False  False  False         True
# 3          False   False  False  False  ...  False  False  False         True
# 4          False   False  False  False  ...  False  False  False         True
# ...          ...     ...    ...    ...  ...    ...    ...    ...          ...
# 2996       False   False  False  False  ...  False  False  False         True
# 2997       False   False  False  False  ...  False  False  False         True
# 2998       False   False  False  False  ...  False  False  False         True
# 2999       False   False  False  False  ...  False  False  False         True
# 3000       False   False  False  False  ...  False  False  False         True
#
# [3001 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Player            0
# Span              0
# Mat               0
# Inns              0
# NO                0
# Runs              0
# HS                0
# Ave               0
# 100               0
# 50                0
# 0                 0
# Unnamed: 11    3001
# dtype: int64

# %% [markdown]
# **CLEANING THE DATA**

# %%
df.drop('Unnamed: 11', axis = 1)
# Out:
#       Unnamed: 0                Player       Span  Mat  ...    Ave 100  50   0
# 0              0  SR Tendulkar (INDIA)  1989-2013  200  ...  53.78  51  68  14
# 1              1      RT Ponting (AUS)  1995-2012  168  ...  51.85  41  62  17
# 2              2    JH Kallis (ICC/SA)  1995-2013  166  ...  55.37  45  58  16
# 3              3  R Dravid (ICC/INDIA)  1996-2012  164  ...  52.31  36  63   8
# 4              4         AN Cook (ENG)  2006-2018  161  ...  45.35  33  57   9
# ...          ...                   ...        ...  ...  ...    ...  ..  ..  ..
# 2996          46       CA Snedden (NZ)  1947-1947    1  ...      -   -   -   -
# 2997          47      VN Swamy (INDIA)  1955-1955    1  ...      -   -   -   -
# 2998          48  Usman Shinwari (PAK)  2019-2019    1  ...      -   -   -   -
# 2999          49    CM Willoughby (SA)  2003-2003    2  ...      -   -   -   -
# 3000           0       JW Wilson (AUS)  1956-1956    1  ...      -   -   -   -
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3001 entries, 0 to 3000
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3001 non-null   int64
#  1   Player       3001 non-null   object
#  2   Span         3001 non-null   object
#  3   Mat          3001 non-null   int64
#  4   Inns         3001 non-null   object
#  5   NO           3001 non-null   object
#  6   Runs         3001 non-null   object
#  7   HS           3001 non-null   object
#  8   Ave          3001 non-null   object
#  9   100          3001 non-null   object
#  10  50           3001 non-null   object
#  11  0            3001 non-null   object
#  12  Unnamed: 11  0 non-null      float64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 304.9+ KB

# %% [markdown]
# **HEATMAP**

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# **LINEMAP**

# %%
plt.figure(figsize = (10,5))
sns.lineplot(data=df,x = 'Mat',y = 'HS')
plt.title('lineplot')
# Out:
# Text(0.5, 1.0, 'lineplot')

# %%
sns.lineplot(data=df, x = 'Mat', y = '100')
plt.title('lineplot')
# Out:
# Text(0.5, 1.0, 'lineplot')

# %% [markdown]
# **SCATTERPLOT**

# %%
sns.scatterplot(data=df,x = 'Mat' ,y = '100')
plt.title('Pairplot')
# Out:
# Text(0.5, 1.0, 'Pairplot')

# %% [markdown]
# **CATPLOT**

# %%
sns.catplot(data=df, x = 'Mat', y = '50')
plt.title('Catplot')
# Out:
# Text(0.5, 1.0, 'Catplot')

# %% [markdown]
# **BARPLOT**

# %%
sns.barplot(data=df, x = 'Mat', y = '100')
plt.title('barplot')
# Out:
# Text(0.5, 1.0, 'barplot')

# %% [markdown]
# **PAIRPLOT**

# %%
sns.pairplot(df)
plt.title('Pairplot')
# Out:
# Text(0.5, 1.0, 'Pairplot')

# %% [markdown]
# **RELPLOT**

# %%
sns.relplot(data=df, x = 'Mat', y = '100')
plt.title('Relplot')
# Out:
# Text(0.5, 1.0, 'Relplot')
